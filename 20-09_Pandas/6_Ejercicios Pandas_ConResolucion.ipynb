# %% [markdown]
# ## Series:

# %% [markdown]
# ### 1. Crear una Serie con Calificaciones de Estudiantes
#
# Enunciado:
#
# Crea una Serie en Pandas que contenga los nombres de 5 estudiantes ( Debe incluir al uno que se llame Juan) como índices y sus calificaciones en matemáticas como valores.
#
# Imprime la Serie y muestra la calificación del estudiante con índice 'Juan'.

# %%
import pandas as pd

# Crear la Serie
calificaciones = pd.Series({'Ana': 8.5, 'Juan': 7.0, 'María': 9.2, 'Luis': 6.8, 'Carlos': 7.5})
print("Serie de calificaciones:")
print(calificaciones)

# Mostrar la calificación de Juan
print("\nCalificación de Juan:", calificaciones['Juan'])

# %% [markdown]
# ### 2. Filtrar Estudiantes Aprobados
#
# Enunciado:
#
# Usando la Serie del ejercicio anterior, filtra los estudiantes que aprobaron (nota >= 7) y muéstralos.

# %%
# Filtrar estudiantes aprobados
aprobados = calificaciones[calificaciones >= 7]
print("\nEstudiantes aprobados:")
print(aprobados)

# %% [markdown]
# ### 3. Calcular el Promedio de Notas
#
# Enunciado:
#
# Calcula e imprime el promedio de las calificaciones de todos los estudiantes.

# %%
# Calcular promedio
promedio = calificaciones.mean()
print("\nPromedio de calificaciones:", promedio)

# %% [markdown]
# ### 4. Comparar Dos Series de Calificaciones
#
# Enunciado:
#
# A partir de las dos Series que representen las calificaciones de los mismos estudiantes en dos materias diferentes.
#
# Calcula la diferencia de calificaciones entre las dos materias para cada estudiante.

# %%
# Calificaciones en dos materias
calificaciones_matematicas = pd.Series({'Ana': 8.5, 'Juan': 7.0, 'María': 9.2, 'Luis': 6.8, 'Carlos': 7.5})
calificaciones_historia = pd.Series({'Ana': 7.5, 'Juan': 8.0, 'María': 8.8, 'Luis': 7.0, 'Carlos': 6.5})

# %%
# Diferencia de calificaciones
diferencia = calificaciones_matematicas - calificaciones_historia
print("Diferencia entre calificaciones:")
print(diferencia)

# %% [markdown]
# ### 5. Serie de Datos sobre Ventas
#
# Enunciado:
#
# A partir de la Serie que contiene las ventas diarias (en euros) de una tienda durante 7 días.
#
# Calcula:
#
# - El total de ventas
#
# - El promedio de ventas
#
# - El día con mayor venta
#
# - La venta mas baja de la semana

# %%
# Crear la Serie
ventas = pd.Series({'Lunes': 100, 'Martes': 150, 'Miércoles': 200, 'Jueves': 180, 'Viernes': 220, 'Sábado': 300, 'Domingo': 250})

# %%
# Calcular métricas
total_ventas = ventas.sum()
promedio_ventas = ventas.mean()
dia_mayor_venta = ventas.idxmax()
venta_minima= ventas.min()

print("Total de ventas:", total_ventas)
print("Promedio de ventas:", promedio_ventas)
print("Día con mayor venta:", dia_mayor_venta)
print("Venta mas baja:", venta_minima)

# %% [markdown]
# ### 6. Datos de Temperaturas Semanales
#
# Enunciado:
#
# Dada una Serie que contiene las temperaturas promedio de 7 días en una ciudad.
#
# - Filtra los días con temperaturas por debajo de la media
#
# - Encuentra la temperatura más alta
#
# - El día correspondiente.

# %%
# Crear la Serie
temperaturas = pd.Series({'Lunes': 15, 'Martes': 18, 'Miércoles': 20, 'Jueves': 22, 'Viernes': 19, 'Sábado': 21, 'Domingo': 16})

# %%
# Calcular la media
media = temperaturas.mean()

# Filtrar días con temperaturas por debajo de la media
dias_frios = temperaturas[temperaturas < media]

# Día con la temperatura más alta
dia_calor = temperaturas.idxmax()
temp_max = temperaturas.max()

print(f"Temperatura Media de la semana: {media:0.2f}")
print("Días con temperaturas por debajo de la media:")
print(dias_frios)
print("\nDía más cálido:", dia_calor, "con", temp_max, "°C")

# %% [markdown]
# ## DataFrame:

# %% [markdown]
# ### Ejercicio 1: Identificar valores nulos en un dataset
#
# Enunciado:
#
# Tienes un dataset que contiene información sobre productos en un inventario con las columnas Nombre, Precio y Cantidad. Algunos productos no tienen datos completos.
#
# Identifica las filas que contienen valores nulos.
#
# Cuenta cuántos valores nulos hay en cada columna.
#
# Objetivo: Usar isnull() y sum() para trabajar con valores nulos.

# %%
import pandas as pd
import numpy as np

# Crear un DataFrame con valores nulos
datos = {
    'Producto': ['Laptop', 'Teléfono', 'Tablet', np.nan],
    'Precio': [1200, 800, np.nan, 500],
    'Stock': [10, 5, 7, np.nan]
}
df = pd.DataFrame(datos)

df

# %%
# Detectar valores nulos
print("¿Hay valores nulos?\n", df.isnull())

# Contar valores nulos por columna
print("\nNúmero de valores nulos por columna:\n", df.isnull().sum())

# %% [markdown]
# ### Ejercicio 2: Eliminar valores nulos
# Enunciado:
#
# Usa el dataset del ejercicio anterior y realiza lo siguiente:
#
# Elimina todas las filas que contienen valores nulos.
#
# Rellena los valores nulos en la columna Precio con el valor promedio de los precios.

# %%
# Eliminar filas con valores nulos
df_sin_nulos = df.dropna()
print("DataFrame sin valores nulos:\n", df_sin_nulos)

# Rellenar valores nulos en la columna Precio con el promedio
promedio_precio = df['Precio'].mean()
df['Precio'] = df['Precio'].fillna(promedio_precio)
print("\nDataFrame con valores nulos en 'Precio' reemplazados por el promedio:\n", df)

# %%
# Crear un DataFrame con tipos inconsistentes
datos = {
    'Nombre': ['María', 'Luis', 'Carmen', 'Antonio'],
    'Edad': [18, 'veintidós', 20, 21],  # Un dato no numérico
    'Promedio': [8.5, 7.3, '9,1', 6.8]  # Número como texto
}
df = pd.DataFrame(datos)

# %%
# Acceder al valor de la fila 0 en la columna 'Nombre'
print(df.loc[0, 'Nombre'])  # Salida: 'María'

# Acceder a la columna 'Edad'
print(df['Edad'])

# %% [markdown]
# ---

# %% [markdown]
# Se desea analizar la evolución de varios índices bursátiles internacionales desde el año 1994 hasta 2018.
#
# Para ello, comienza leyendo el archivo Index2018.csv desde una URL.
#
# Luego, realiza una copia del DataFrame original para trabajar sobre ella sin modificar los datos base.
#
# link: https://raw.githubusercontent.com/MaddoSaru/curso-series-temporales/master/1.%20Introduccion%20a%20las%20series%20temporales/Python/Index2018.csv

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats

# %%
raw_csv_data = pd.read_csv("https://raw.githubusercontent.com/MaddoSaru/curso-series-temporales/master/1.%20Introduccion%20a%20las%20series%20temporales/Python/Index2018.csv")

# %%
df_comp = raw_csv_data.copy()

# %%
df_comp.head()
# Out:
#          date     spx      dax     ftse    nikkei
# 0  07/01/1994  469.90  2224.95  3445.98  18124.01
# 1  10/01/1994  475.27  2225.00  3440.58  18443.44
# 2  11/01/1994  474.13  2228.10  3413.77  18485.25
# 3  12/01/1994  474.17  2182.06  3372.02  18793.88
# 4  13/01/1994  472.47  2142.37  3360.01  18577.26

# %% [markdown]
# ### Estadísticas descriptivas de los índices bursátiles
#
# Calcula un resumen estadístico básico para los índices bursátiles disponibles (spx, dax, ftse, nikkei) usando .describe().
#
# Este método te permitirá obtener:
#
# Media,
#
# Desviación estándar,
#
# Valores mínimo y máximo,
#
# Cuartiles (25%, 50%, 75%).
#
# Esta visión general te ayudará a identificar rangos, dispersión y posibles outliers en cada mercado antes de aplicar técnicas más avanzadas de análisis.

# %%
df_comp.describe()
# Out:
#                spx           dax         ftse        nikkei
# count  6269.000000   6269.000000  6269.000000   6269.000000
# mean   1288.127542   6080.063363  5422.713545  14597.055700
# std     487.586473   2754.361032  1145.572428   4043.122953
# min     438.920000   1911.700000  2876.600000   7054.980000
# 25%     990.671905   4069.350000  4486.100000  10709.290000
# 50%    1233.420000   5773.340000  5662.430000  15028.170000
# 75%    1459.987747   7443.070000  6304.250000  17860.470000
# max    2872.867839  13559.600000  7778.637689  24124.150000

# %% [markdown]
# ### Exploración estructural del DataFrame
#
# Para comprender mejor la estructura del DataFrame, inspecciona información clave como:
#
# - Número de filas y columnas,
#
# - Tipos de datos por columna,
#
# - Número de valores no nulos en cada variable.
#
# Usa el método .info() para obtener esta visión general y así asegurarte de que las columnas tienen el tipo de dato correcto, especialmente la columna date (que debe estar como datetime64 tras su conversión).

# %%
df_comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6269 entries, 0 to 6268
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    6269 non-null   object
#  1   spx     6269 non-null   float64
#  2   dax     6269 non-null   float64
#  3   ftse    6269 non-null   float64
#  4   nikkei  6269 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 245.0+ KB

# %% [markdown]
# ### Conversión de columna date a tipo datetime
#
# Los datos vienen con la fecha en formato string.
#
# Convierte la columna date al tipo datetime y establece dicha columna como índice del DataFrame para facilitar operaciones de series temporales.

# %%
df_comp["date"] = pd.to_datetime(df_comp["date"], format="%d/%m/%Y")
# Establecer la columna 'date' como índice del DataFrame
df_comp.set_index("date", inplace=True)
df_comp
# Out:
#                     spx       dax         ftse    nikkei
# date
# 1994-01-07   469.900000   2224.95  3445.980000  18124.01
# 1994-01-10   475.270000   2225.00  3440.580000  18443.44
# 1994-01-11   474.130000   2228.10  3413.770000  18485.25
# 1994-01-12   474.170000   2182.06  3372.020000  18793.88
# 1994-01-13   472.470000   2142.37  3360.010000  18577.26
# ...                 ...       ...          ...       ...
# 2018-01-23  2839.130362  13559.60  7731.827774  24124.15
# 2018-01-24  2837.544008  13414.74  7643.428966  23940.78
# 2018-01-25  2839.253031  13298.36  7615.839954  23669.49
# 2018-01-26  2872.867839  13340.17  7665.541292  23631.88
# 2018-01-29  2853.528411  13324.48  7671.533300  23629.34
#
# [6269 rows x 4 columns]

# %% [markdown]
# ### Detección de valores nulos en los datos bursátiles
#
# Antes de continuar con el análisis, es importante verificar la calidad de los datos.
#
# Utiliza Pandas para detectar la presencia de valores nulos o faltantes en el DataFrame.
#
# Este paso es clave para evitar errores en cálculos posteriores como medias, resampleo o visualización.

# %%
df_comp.isna()
# Out:
#               spx    dax   ftse  nikkei
# date
# 1994-01-07  False  False  False   False
# 1994-01-10  False  False  False   False
# 1994-01-11  False  False  False   False
# 1994-01-12  False  False  False   False
# 1994-01-13  False  False  False   False
# ...           ...    ...    ...     ...
# 2018-01-23  False  False  False   False
# 2018-01-24  False  False  False   False
# 2018-01-25  False  False  False   False
# 2018-01-26  False  False  False   False
# 2018-01-29  False  False  False   False
#
# [6269 rows x 4 columns]

# %%
df_comp.isna().sum()
# Out:
# spx       0
# dax       0
# ftse      0
# nikkei    0
# dtype: int64

# %% [markdown]
# ### Visualización de evolución histórica del SPX
#
# Realiza un gráfico temporal que muestre la evolución del índice SPX (S&P 500) a lo largo del tiempo.
#
# ¿Qué patrones visuales puedes observar? ¿Existe una tendencia clara?

# %%
df_comp.spx.plot(figsize=(20,5), title = "S&P500 Prices")
plt.show()

# %% [markdown]
# ### Visualización de la evolución del índice FTSE100
#
# Realiza un gráfico de líneas que muestre la evolución temporal del índice FTSE100.
#
# Ajusta el tamaño del gráfico (figsize) para una mejor visualización a lo largo del tiempo y agrega un título descriptivo.
#
# Este gráfico te permitirá identificar tendencias generales, fluctuaciones abruptas y posibles eventos económicos que hayan impactado en el mercado británico.

# %%
df_comp.ftse.plot(figsize=(20,5), title = "FTSE100 Prices")
plt.show()

# %% [markdown]
# ### Comparativa visual entre los índices S&P500 y FTSE100
#
# Compara gráficamente la evolución de los índices S&P500 (EE.UU.) y FTSE100 (Reino Unido) a lo largo del tiempo.
#
# Grafica ambas series temporalmente con un tamaño adecuado (figsize=(20,5)) y personaliza el título del gráfico para reflejar que se trata de una comparación entre mercados.
#
# Este análisis visual permite:
#
# Identificar correlaciones o divergencias en el comportamiento de ambos índices,
#
# Observar cómo reaccionan a eventos globales,
#
# Detectar períodos en los que uno supera sistemáticamente al otro.

# %%
df_comp.spx.plot(figsize=(20,5), title = "S&P500 Prices")
df_comp.ftse.plot(figsize=(20,5), title = "FTSE100 Prices")
plt.title("S&P vs FTSE")
plt.show()

# %% [markdown]
# ### Análisis de normalidad con QQ Plot sobre el índice S&P500
#
# Realiza un gráfico QQ Plot (Quantile-Quantile Plot) sobre la serie temporal del índice S&P500 para evaluar si sus valores se distribuyen de forma aproximadamente normal (gaussiana).
#
# Este tipo de gráfico compara los cuantiles teóricos de una distribución normal con los cuantiles reales de los datos:
#
# Si los puntos se alinean aproximadamente en una línea recta, los datos siguen una distribución normal.
#
# Desviaciones en los extremos indican colas más pesadas o ligeras.
#
# El análisis de normalidad es crucial en finanzas cuando se aplican modelos estadísticos que asumen normalidad de los rendimientos, como modelos de VaR o análisis de riesgos.

# %%
scipy.stats.probplot(df_comp.spx, plot =  plt)
plt.title("QQ Plot", size = 24)
plt.show()

# %% [markdown]
# Prophet es una librería desarrollada por Meta (Facebook) diseñada para realizar predicciones en series temporales de forma sencilla, interpretativa y automática.
# Se adapta muy bien a datos con:
#
# Tendencias de largo plazo,
#
# Estacionalidades (diaria, semanal, anual),
#
# Festivos o eventos especiales.
#
# Prophet combina un modelo aditivo que incluye:
#
# Crecimiento lineal o logístico,
#
# Estacionalidad expresada como funciones periódicas,
#
# Efectos de días festivos,
#
# Y un componente de ruido (residual).
#
# Es muy útil cuando necesitas un modelo rápido, interpretable y reproducible sin configurar complejos modelos ARIMA o redes neuronales

# %% [markdown]
# ### Predicción del índice S&P500 con Prophet
#
# Se desea realizar una predicción a corto plazo sobre el comportamiento del índice bursátil S&P500 usando el modelo de series temporales Prophet.
#
# Para ello:
#
# Convierte el dataset a un formato compatible con Prophet (ds como fecha y y como valor a predecir).
#
# Ajusta un modelo Prophet sin estacionalidad diaria, ya que los datos son financieros (y no hay datos los fines de semana).
#
# Genera una predicción para los próximos 90 días.
#
# Grafica los resultados mostrando tanto la predicción como el intervalo de confianza.

# %%
from prophet import Prophet
import pandas as pd
import matplotlib.pyplot as plt

# Preparamos los datos
df_prophet = df_comp[['spx']].reset_index().rename(columns={"date": "ds", "spx": "y"})
df_prophet
# Out:
#              ds            y
# 0    1994-01-07   469.900000
# 1    1994-01-10   475.270000
# 2    1994-01-11   474.130000
# 3    1994-01-12   474.170000
# 4    1994-01-13   472.470000
# ...         ...          ...
# 6264 2018-01-23  2839.130362
# 6265 2018-01-24  2837.544008
# 6266 2018-01-25  2839.253031
# 6267 2018-01-26  2872.867839
# 6268 2018-01-29  2853.528411
#
# [6269 rows x 2 columns]

# %%
# Creamos el modelo y lo entrenamos
modelo = Prophet(daily_seasonality=False)
modelo.fit(df_prophet)
# Out:
# 00:28:31 - cmdstanpy - INFO - Chain [1] start processing
# 00:28:34 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Creamos un DataFrame de fechas futuras , realizamos la predicciones
futuro = modelo.make_future_dataframe(periods=360)  # predicción a 90 días
forecast = modelo.predict(futuro)
forecast
# Out:
#              ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0    1994-01-07   441.574151   365.236061   526.382955   441.574151
# 1    1994-01-10   441.887203   361.822760   527.069990   441.887203
# 2    1994-01-11   441.991554   363.069911   532.776005   441.991554
# 3    1994-01-12   442.095905   359.583960   531.446331   442.095905
# 4    1994-01-13   442.200255   361.059285   534.375637   442.200255
# ...         ...          ...          ...          ...          ...
# 6624 2019-01-20  2709.394777  2585.661847  2861.901758  2593.020629
# 6625 2019-01-21  2709.908232  2564.523940  2849.712600  2592.768515
# 6626 2019-01-22  2710.421687  2563.061458  2848.505056  2592.548061
# 6627 2019-01-23  2710.935142  2559.604744  2846.703484  2592.327608
# 6628 2019-01-24  2711.448596  2567.409135  2841.689358  2592.119574
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0      441.574151        5.368265              5.368265              5.368265
# 1      441.887203        4.558051              4.558051              4.558051
# 2      441.991554        4.675439              4.675439              4.675439
# 3      442.095905        4.362661              4.362661              4.362661
# 4      442.200255        4.043136              4.043136              4.043136
# ...           ...             ...                   ...                   ...
# 6624  2816.910860       15.919751             15.919751             15.919751
# 6625  2817.906663       -3.565965             -3.565965             -3.565965
# 6626  2818.902466       -4.264685             -4.264685             -4.264685
# 6627  2819.898269       -5.264608             -5.264608             -5.264608
# 6628  2820.894072       -6.127362             -6.127362             -6.127362
#
#          weekly  weekly_lower  weekly_upper     yearly  yearly_lower  \
# 0     -4.886613     -4.886613     -4.886613  10.254877     10.254877
# 1     -5.573713     -5.573713     -5.573713  10.131764     10.131764
# 2     -5.182744     -5.182744     -5.182744   9.858183      9.858183
# 3     -5.103061     -5.103061     -5.103061   9.465721      9.465721
# 4     -4.913483     -4.913483     -4.913483   8.956620      8.956620
# ...         ...           ...           ...        ...           ...
# 6624  12.829800     12.829800     12.829800   3.089950      3.089950
# 6625  -5.573713     -5.573713     -5.573713   2.007748      2.007748
# 6626  -5.182744     -5.182744     -5.182744   0.918059      0.918059
# 6627  -5.103061     -5.103061     -5.103061  -0.161547     -0.161547
# 6628  -4.913483     -4.913483     -4.913483  -1.213879     -1.213879
#
#       yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0        10.254877                   0.0                         0.0
# 1        10.131764                   0.0                         0.0
# 2         9.858183                   0.0                         0.0
# 3         9.465721                   0.0                         0.0
# 4         8.956620                   0.0                         0.0
# ...            ...                   ...                         ...
# 6624      3.089950                   0.0                         0.0
# 6625      2.007748                   0.0                         0.0
# 6626      0.918059                   0.0                         0.0
# 6627     -0.161547                   0.0                         0.0
# 6628     -1.213879                   0.0                         0.0
#
#       multiplicative_terms_upper         yhat
# 0                            0.0   446.942416
# 1                            0.0   446.445254
# 2                            0.0   446.666993
# 3                            0.0   446.458565
# 4                            0.0   446.243392
# ...                          ...          ...
# 6624                         0.0  2725.314528
# 6625                         0.0  2706.342267
# 6626                         0.0  2706.157002
# 6627                         0.0  2705.670534
# 6628                         0.0  2705.321234
#
# [6629 rows x 19 columns]

# %%
# Definimos hasta dónde son datos históricos
ultima_fecha_real = df_prophet['ds'].max()
ultima_fecha_real
# Out:
# Timestamp('2018-01-29 00:00:00')

# %%
# Separar predicción en histórico y futuro
historico = forecast[forecast['ds'] <= ultima_fecha_real]
historico
# Out:
#              ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0    1994-01-07   441.574151   365.236061   526.382955   441.574151
# 1    1994-01-10   441.887203   361.822760   527.069990   441.887203
# 2    1994-01-11   441.991554   363.069911   532.776005   441.991554
# 3    1994-01-12   442.095905   359.583960   531.446331   442.095905
# 4    1994-01-13   442.200255   361.059285   534.375637   442.200255
# ...         ...          ...          ...          ...          ...
# 6264 2018-01-23  2523.524152  2433.154888  2601.896752  2523.524152
# 6265 2018-01-24  2524.037607  2436.962690  2601.726763  2524.037607
# 6266 2018-01-25  2524.551062  2433.143763  2607.204137  2524.551062
# 6267 2018-01-26  2525.064517  2436.154300  2601.876234  2525.064517
# 6268 2018-01-29  2526.604881  2428.930232  2601.615243  2526.604881
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0      441.574151        5.368265              5.368265              5.368265
# 1      441.887203        4.558051              4.558051              4.558051
# 2      441.991554        4.675439              4.675439              4.675439
# 3      442.095905        4.362661              4.362661              4.362661
# 4      442.200255        4.043136              4.043136              4.043136
# ...           ...             ...                   ...                   ...
# 6264  2523.524152       -5.610587             -5.610587             -5.610587
# 6265  2524.037607       -6.573818             -6.573818             -6.573818
# 6266  2524.551062       -7.379573             -7.379573             -7.379573
# 6267  2525.064517       -8.285637             -8.285637             -8.285637
# 6268  2526.604881      -11.275765            -11.275765            -11.275765
#
#         weekly  weekly_lower  weekly_upper     yearly  yearly_lower  \
# 0    -4.886613     -4.886613     -4.886613  10.254877     10.254877
# 1    -5.573713     -5.573713     -5.573713  10.131764     10.131764
# 2    -5.182744     -5.182744     -5.182744   9.858183      9.858183
# 3    -5.103061     -5.103061     -5.103061   9.465721      9.465721
# 4    -4.913483     -4.913483     -4.913483   8.956620      8.956620
# ...        ...           ...           ...        ...           ...
# 6264 -5.182744     -5.182744     -5.182744  -0.427844     -0.427844
# 6265 -5.103061     -5.103061     -5.103061  -1.470757     -1.470757
# 6266 -4.913483     -4.913483     -4.913483  -2.466089     -2.466089
# 6267 -4.886613     -4.886613     -4.886613  -3.399024     -3.399024
# 6268 -5.573713     -5.573713     -5.573713  -5.702052     -5.702052
#
#       yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0        10.254877                   0.0                         0.0
# 1        10.131764                   0.0                         0.0
# 2         9.858183                   0.0                         0.0
# 3         9.465721                   0.0                         0.0
# 4         8.956620                   0.0                         0.0
# ...            ...                   ...                         ...
# 6264     -0.427844                   0.0                         0.0
# 6265     -1.470757                   0.0                         0.0
# 6266     -2.466089                   0.0                         0.0
# 6267     -3.399024                   0.0                         0.0
# 6268     -5.702052                   0.0                         0.0
#
#       multiplicative_terms_upper         yhat
# 0                            0.0   446.942416
# 1                            0.0   446.445254
# 2                            0.0   446.666993
# 3                            0.0   446.458565
# 4                            0.0   446.243392
# ...                          ...          ...
# 6264                         0.0  2517.913565
# 6265                         0.0  2517.463789
# 6266                         0.0  2517.171489
# 6267                         0.0  2516.778880
# 6268                         0.0  2515.329116
#
# [6269 rows x 19 columns]

# %%
futuro_pred = forecast[forecast['ds'] > ultima_fecha_real]
futuro_pred
# Out:
#              ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 6269 2018-01-30  2527.118336  2427.862286  2602.632123  2527.118336
# 6270 2018-01-31  2527.631790  2425.631367  2594.913783  2527.631790
# 6271 2018-02-01  2528.145245  2427.741053  2602.414711  2528.145245
# 6272 2018-02-02  2528.658700  2434.692186  2600.206100  2528.658700
# 6273 2018-02-03  2529.172155  2450.968165  2615.841835  2529.172155
# ...         ...          ...          ...          ...          ...
# 6624 2019-01-20  2709.394777  2585.661847  2861.901758  2593.020629
# 6625 2019-01-21  2709.908232  2564.523940  2849.712600  2592.768515
# 6626 2019-01-22  2710.421687  2563.061458  2848.505056  2592.548061
# 6627 2019-01-23  2710.935142  2559.604744  2846.703484  2592.327608
# 6628 2019-01-24  2711.448596  2567.409135  2841.689358  2592.119574
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 6269  2527.118336      -11.457625            -11.457625            -11.457625
# 6270  2527.631790      -11.844685            -11.844685            -11.844685
# 6271  2528.145245      -12.014472            -12.014472            -12.014472
# 6272  2528.658700      -12.240922            -12.240922            -12.240922
# 6273  2529.172155        5.324352              5.324352              5.324352
# ...           ...             ...                   ...                   ...
# 6624  2816.910860       15.919751             15.919751             15.919751
# 6625  2817.906663       -3.565965             -3.565965             -3.565965
# 6626  2818.902466       -4.264685             -4.264685             -4.264685
# 6627  2819.898269       -5.264608             -5.264608             -5.264608
# 6628  2820.894072       -6.127362             -6.127362             -6.127362
#
#          weekly  weekly_lower  weekly_upper    yearly  yearly_lower  \
# 6269  -5.182744     -5.182744     -5.182744 -6.274882     -6.274882
# 6270  -5.103061     -5.103061     -5.103061 -6.741624     -6.741624
# 6271  -4.913483     -4.913483     -4.913483 -7.100989     -7.100989
# 6272  -4.886613     -4.886613     -4.886613 -7.354309     -7.354309
# 6273  12.829813     12.829813     12.829813 -7.505461     -7.505461
# ...         ...           ...           ...       ...           ...
# 6624  12.829800     12.829800     12.829800  3.089950      3.089950
# 6625  -5.573713     -5.573713     -5.573713  2.007748      2.007748
# 6626  -5.182744     -5.182744     -5.182744  0.918059      0.918059
# 6627  -5.103061     -5.103061     -5.103061 -0.161547     -0.161547
# 6628  -4.913483     -4.913483     -4.913483 -1.213879     -1.213879
#
#       yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 6269     -6.274882                   0.0                         0.0
# 6270     -6.741624                   0.0                         0.0
# 6271     -7.100989                   0.0                         0.0
# 6272     -7.354309                   0.0                         0.0
# 6273     -7.505461                   0.0                         0.0
# ...            ...                   ...                         ...
# 6624      3.089950                   0.0                         0.0
# 6625      2.007748                   0.0                         0.0
# 6626      0.918059                   0.0                         0.0
# 6627     -0.161547                   0.0                         0.0
# 6628     -1.213879                   0.0                         0.0
#
#       multiplicative_terms_upper         yhat
# 6269                         0.0  2515.660710
# 6270                         0.0  2515.787105
# 6271                         0.0  2516.130773
# 6272                         0.0  2516.417778
# 6273                         0.0  2534.496507
# ...                          ...          ...
# 6624                         0.0  2725.314528
# 6625                         0.0  2706.342267
# 6626                         0.0  2706.157002
# 6627                         0.0  2705.670534
# 6628                         0.0  2705.321234
#
# [360 rows x 19 columns]

# %% [markdown]
# | Columna          | Descripción                                                  |
# | ---------------- | ------------------------------------------------------------ |
# | `ds`             | Fecha de la predicción                                       |
# | `yhat`           | Valor **predicho** para esa fecha                            |
# | `yhat_lower`     | Límite inferior del intervalo de confianza (por defecto 80%) |
# | `yhat_upper`     | Límite superior del intervalo de confianza                   |
# | `trend`          | Componente de tendencia estimado                             |
# | `additive_terms` | Suma de los componentes (tendencia, estacionalidad, etc.)    |

# %%
# Graficamos ambas partes
plt.figure(figsize=(15, 6))
plt.plot(historico['ds'], historico['yhat'], label="Histórico", color="blue")
plt.plot(futuro_pred['ds'], futuro_pred['yhat'], label="Predicción futura", color="red")
plt.fill_between(futuro_pred['ds'], futuro_pred['yhat_lower'], futuro_pred['yhat_upper'],
                 color="red", alpha=0.5, label="Intervalo de confianza")
plt.title("Forecast del índice S&P500 con Prophet")
plt.xlabel("Fecha")
plt.ylabel("Precio estimado")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
